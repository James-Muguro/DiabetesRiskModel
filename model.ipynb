# %%
pip install pandas numpy seaborn matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import essential libraries for data analysis and visualization
import pandas as pd           # For data manipulation and analysis
import numpy as np            # For numerical computations
import seaborn as sns         # For advanced data visualization
import matplotlib.pyplot as plt  # For plotting

# Enable inline plotting for Jupyter notebooks
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Load the diabetes dataset from a CSV file into a DataFrame
diabetes_data = pd.read_csv('diabetes.csv')

# Display the first five rows of the DataFrame to understand the data structure and contents
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
# Generate descriptive statistics for the diabetes dataset
# This includes measures such as count, mean, standard deviation, 
# minimum, maximum, and quartiles for each numerical feature
diabetes_data.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
# Display information about the diabetes dataset, including data types,
# non-null counts, and memory usage. This helps assess data quality 
# and identify potential issues with missing values.
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
# Plot histograms for each numerical feature in the diabetes dataset
# This visualization helps to understand the distribution of the data
# 'bins' specifies the number of intervals to group the data
# 'figsize' sets the dimensions of the plot
diabetes_data.hist(bins=10, figsize=(10, 10))

# Display the histograms
plt.show()

# %%
# Calculate and visualize the correlation matrix for the diabetes dataset
# A heatmap is used to display the relationships between features
# The correlation matrix helps identify potential dependencies and interactions

plt.figure(figsize=(10, 8))  # Set the size of the heatmap
sns.heatmap(diabetes_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')

# Add a title for clarity
plt.title('Correlation Heatmap of Diabetes Dataset')

# Observations:
# - Skin thickness, insulin, pregnancies, and age are independent of each other.
# - Age and pregnancies exhibit a negative correlation.
plt.show()

# %%
# Count and visualize the distribution of the target variable 'Outcome'
# This plot displays the number of patients classified as 0 (no diabetes)
# and 1 (diabetes) to provide insights into the dataset's balance

plt.figure(figsize=(8, 6))  # Set the size of the countplot
sns.countplot(y=diabetes_data['Outcome'], palette='Set1', hue=diabetes_data['Outcome'], legend=False)

# Add labels and title for better context
plt.xlabel('Number of Patients')
plt.ylabel('Diabetes Outcome (0: No Diabetes, 1: Diabetes)')
plt.title('Distribution of Diabetes Outcomes in the Dataset')

# Display the countplot
plt.show()

# %%
# Set the aesthetic style of the plots to "ticks" for better visual appeal
sns.set(style="ticks")

# Create a pairplot to visualize the relationships between numerical features
# The 'hue' parameter differentiates data points based on the 'Outcome' variable
# This allows for easier identification of patterns and interactions between features

sns.pairplot(diabetes_data, hue="Outcome")

# Display the pairplot
plt.suptitle('Pairplot of Diabetes Dataset Features', y=1.02)  # Add a title for context
plt.show()

# %%
# Set the aesthetic style of the plots to "whitegrid" for better clarity and visibility
sns.set(style="whitegrid")

# Create a box plot to visualize the distribution of numerical features
# This plot helps identify outliers and understand the spread of the data
# The 'figsize' parameter sets the dimensions of the plot for better visualization

plt.figure(figsize=(15, 6))  # Define the size of the box plot
diabetes_data.boxplot()

# Add a title to provide context
plt.title('Box Plot of Numerical Features in Diabetes Dataset')

# Display the box plot
plt.show()

# %%
# Set the aesthetic style of the plots to "whitegrid" for better clarity
sns.set(style="whitegrid")

# Create box plots for selected features to visualize their distributions and identify outliers

# Box plot for Insulin levels
plt.figure(figsize=(4, 2))  # Set the size of the plot
sns.boxplot(x=diabetes_data['Insulin'])
plt.title('Box Plot of Insulin Levels')  # Add title for context
plt.show()

# Box plot for Blood Pressure levels
plt.figure(figsize=(4, 2))  # Set the size of the plot
sns.boxplot(x=diabetes_data['BloodPressure'])
plt.title('Box Plot of Blood Pressure Levels')  # Add title for context
plt.show()

# Box plot for Diabetes Pedigree Function
plt.figure(figsize=(4, 2))  # Set the size of the plot
sns.boxplot(x=diabetes_data['DiabetesPedigreeFunction'])
plt.title('Box Plot of Diabetes Pedigree Function')  # Add title for context
plt.show()

# %%
#outlier remove

Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1

print("---Q1--- \n",Q1)
print("\n---Q3--- \n",Q3)
print("\n---IQR---\n",IQR)

#print((df < (Q1 - 1.5 * IQR))|(df > (Q3 + 1.5 * IQR)))

# %%
#outlier remove
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape,df_out.shape
#more than 80 records deleted

# %%
#Scatter matrix after removing outlier
sns.set(style="ticks")
sns.pairplot(df_out, hue="Outcome")
plt.show()

# %%
#lets extract features and targets
X=df_out.drop(columns=['Outcome'])
y=df_out['Outcome']

# %%
#Splitting train test data 80 20 ratio
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2)

# %%
train_X.shape,test_X.shape,train_y.shape,test_y.shape

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,make_scorer
from sklearn.model_selection import cross_validate

def tn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 0]
def fp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 1]
def fn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 0]
def tp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 1]

#cross validation purpose
scoring = {'accuracy': make_scorer(accuracy_score),'prec': 'precision'}
scoring = {'tp': make_scorer(tp), 'tn': make_scorer(tn),
           'fp': make_scorer(fp), 'fn': make_scorer(fn)}

def display_result(result):
    print("TP: ",result['test_tp'])
    print("TN: ",result['test_tn'])
    print("FN: ",result['test_fn'])
    print("FP: ",result['test_fp'])

# %%
#Lets build the model

#Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

acc=[]
roc=[]

clf=LogisticRegression()
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# %%
#Support Vector Machine
from sklearn.svm import SVC

clf=SVC(kernel='linear')
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# %%
#KNN

from sklearn.neighbors import KNeighborsClassifier

clf=KNeighborsClassifier(n_neighbors=3)
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier()
clf.fit(train_X,train_y)

y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# %%
#Naive Bayes Theorem
#import library
from sklearn.naive_bayes import GaussianNB

clf=GaussianNB()
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# %%
#Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier
clf=GradientBoostingClassifier(n_estimators=50,learning_rate=0.2)
clf.fit(train_X,train_y)
y_pred=clf.predict(test_X)
#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)

#find the ROC_AOC curve
rc=roc_auc_score(test_y,y_pred)
roc.append(rc)
print("\nAccuracy {0} ROC {1}".format(ac,rc))

#cross val score
result=cross_validate(clf,train_X,train_y,scoring=scoring,cv=10)
display_result(result)

#display predicted values uncomment below line
#pd.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# %%
#lets plot the bar graph

ax=plt.figure(figsize=(9,4))
plt.bar(['Logistic Regression','SVM','KNN','Random Forest','Naivye Bayes','Gradient Boosting'],acc,label='Accuracy')
plt.ylabel('Accuracy Score')
plt.xlabel('Algortihms')
plt.show()

ax=plt.figure(figsize=(9,4))
plt.bar(['Logistic Regression','SVM','KNN','Random Forest','Naivye Bayes','Gradient Boosting'],roc,label='ROC AUC')
plt.ylabel('ROC AUC')
plt.xlabel('Algortihms')
plt.show()

# %%
#Great....
#Random forest has highest accuracy 98% and ROC_AUC curve 97%
#model can be improve more if we take same count of labels
#in our model 30% is diabetic and 70% no diabetic patient

#model can be improve with fine tunning
